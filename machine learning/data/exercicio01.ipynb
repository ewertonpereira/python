# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
pd.set_option('display.max_columns', 21) # mostra o número máximo de colunas
# link dos dados: https://www.kaggle.com/datasets/harlfoxem/housesalesprediction
dataframe = pd.read_csv('../data/kc_house_data.csv')
dataframe.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
dataframe = dataframe.drop(columns=['id', 'date','zipcode', 'lat', 'long'])
dataframe.tail()
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 21608  360000.0         3       2.50         1530      1131     3.0
# 21609  400000.0         4       2.50         2310      5813     2.0
# 21610  402101.0         2       0.75         1020      1350     2.0
# 21611  400000.0         3       2.50         1600      2388     2.0
# 21612  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 21608           0     0          3      8        1530              0
# 21609           0     0          3      8        2310              0
# 21610           0     0          3      7        1020              0
# 21611           0     0          3      8        1600              0
# 21612           0     0          3      7        1020              0
#
#        yr_built  yr_renovated  sqft_living15  sqft_lot15
# 21608      2009             0           1530        1509
# ...

# %%
x = dataframe.loc[:,dataframe.columns != 'price']
# x = dataframe.drop('price', axis=1)
y = dataframe['price']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3) #  random_state=42

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 6176675.087578057

# %%
model.coef_
# Out:
# array([-4.09315347e+04,  4.29439631e+04,  1.08086690e+02, -9.50736248e-03,
#         2.69766491e+04,  5.69540126e+05,  4.19845523e+04,  1.83754781e+04,
#         1.20554096e+05,  4.93221477e+01,  5.87645425e+01, -3.55976974e+03,
#         1.15336235e+01,  3.20038873e+01, -5.99889667e-01])

# %%
model.predict(x_test)
# Out:
# array([468284.68645912, 544896.54207868, 481831.33972437, ...,
#        290805.26025573, 432147.2325263 , 392460.58001247])

# %%
model.score(x_test, y_test)
# Out:
# 0.6586926410187148
